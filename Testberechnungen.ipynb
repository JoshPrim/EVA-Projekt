# %%
import pandas as pd
import csv
import datetime
import time
import os
import sys
import threading
import numpy as np
import folium
from geopy.geocoders import Nominatim

sys.path.append('./Clients')

from Python_Client import FaSta_Request

# %%
api_key = 'd16d67e35458c895f557696799eb4e8f'

# FaSta API Zugriff
api_zugriff = FaSta_Request(api_key)
liste_aufzüge = api_zugriff.request()

daten = pd.DataFrame(liste_aufzüge)
daten['equipmentnumber'].astype(str).astype('int64')
daten
daten.head(100)
# Out:
# Zugriff wird ausgeführt!
# Verzeichnis erstellt: ./Logs/2018-08-27_16-49-12/
# Request Status Code:  200
# Zurgiff erfolgreich abgeschlossen!
#                       description  equipmentnumber  geocoordX  geocoordY  \
# 0                      zu Gleis 1         10499641  14.671359  51.099399
# 1                    zu Gleis 2/3         10499642  14.671325  51.099552
# 2                    zu Gleis 2/3         10097793   9.635192  52.298212
# 3                    zu Gleis 2/3         10267599   9.500320  48.999396
# 4                      zu Gleis 1         10267598   9.500395  48.999558
# 5                    zu Gleis 6/7         10315764   8.632652  50.068284
# 6        zu Gleis 4/5 Abschnitt A         10547807   8.468618  49.479626
# 7                    zu Gleis 4/5         10315763   8.632774  50.068117
# 8        zu Gleis 2/3 Abschnitt A         10547808   8.468779  49.479755
# 9                      zu Gleis 1         10315762   8.632953  50.067873
# ...

# %%
fdt = pd.unique(daten['equipmentnumber'])

len(fdt)
# Out:
# 2129

# %%
# Einlesen der Stammdaten
aufzüge = pd.read_csv('Stammdaten_Aufzüge.csv', sep= ';', engine='python')

columns = ['Standort Equipment', 'TechnPlatzBezeichng', 'Equipment', 'Equipmentname','Ort','Wirtschaftseinheit','Hersteller',
          'Baujahr','ANTRIEBSART','ANZAHL_HALTESTELLEN','ANZAHL_TUEREN_KABINE', 'ANZAHL_TUEREN_SCHACHT', 'FOERDERGESCHWINDIGKEIT',
           'FOERDERHOEHE', 'LAGE', 'TRAGKRAFT', 'ERWEITERTE_ORTSANGABE', 'MIN_TUERBREITE', 'KABINENTIEFE', 'KABINENBREITE',
           'KABINENHOEHE', 'TUERHOHE', 'FABRIKNUMMER', 'TUERART','GEOKOORDINATERECHTSWERT','GEOKOORDINATEHOCHWERT', 'AUSFTEXTLICHEBESCHREIBUNG']
aufzüge.columns = columns
aufzüge = aufzüge.drop(0)
aufzüge['Equipment'] = aufzüge['Equipment'].astype(str).astype('int64')
aufzüge.head(5)
# Out:
#   Standort Equipment             TechnPlatzBezeichng  Equipment  \
# 1        BAHNSTEIG 1    Bahnsteig 01 Richtung Aachen   10001649
# 2      BAHNSTEIG 6/7        Bahnsteig 02 Richtung MG   10001650
# 3    IM BF AU/SIEG 1  Bahnsteig 02 (Mittelbahnsteig)   10003481
# 4             S-BAHN    Bahnsteig 01 (Hausbahnsteig)   10003482
# 5      TUNNEL ZUM EG                 Empfangsgebäude   10004693
#
#                       Equipmentname            Ort  Wirtschaftseinheit  \
# 1                    Personenaufzug  Aachen Schanz              7205.0
# 2                    Personenaufzug  Aachen Schanz              7205.0
# 3  HA 1013 Personenaufzug Gleis 2/3      Au (Sieg)               204.0
# 4       HA 1016 Personenaufzug Gl.1      Au (Sieg)               204.0
# 5                    Personenaufzug   Bad Oldesloe               317.0
#
#                 Hersteller  Baujahr  ANTRIEBSART ANZAHL_HALTESTELLEN  \
# 1      OTIS GmbH & Co. OHG   2004.0         SEIL                   2
# ...

# %%
# Ältester Aufzug in Deutschland
alter_aufzug = int(aufzüge['Baujahr'].min())
jüngster_aufzug = int(aufzüge['Baujahr'].max())

zeile_alter_aufzug = aufzüge[aufzüge['Baujahr'] == alter_aufzug]
zeile_alter_aufzug = zeile_alter_aufzug[['Baujahr', 'Ort']].reset_index(drop=True)

print('Baujahr des ältesten Aufzugs in Deutschland: ', int(zeile_alter_aufzug['Baujahr']), 'in: ', zeile_alter_aufzug['Ort'])
# Out:
# Baujahr des ältesten Aufzugs in Deutschland:  1948 in:  0    Stuttgart Hbf
# Name: Ort, dtype: object

# %%
# Mappen der Aufzüge auf die Status-Tabelle
daten_mapped = pd.merge(daten, aufzüge, left_on = 'equipmentnumber', right_on = 'Equipment', how = 'left').fillna(0).drop(['Equipment'], axis = 1)


# daten.sort_values(['equipmentnumber'])
# print(aufzüge['Equipment'], daten['equipmentnumber'])

daten_mapped.head()
# Out:
#     description  equipmentnumber  geocoordX  geocoordY   state  \
# 0    zu Gleis 1         10499641  14.671359  51.099399  ACTIVE
# 1  zu Gleis 2/3         10499642  14.671325  51.099552  ACTIVE
# 2  zu Gleis 2/3         10097793   9.635192  52.298212  ACTIVE
# 3  zu Gleis 2/3         10267599   9.500320  48.999396  ACTIVE
# 4    zu Gleis 1         10267598   9.500395  48.999558  ACTIVE
#
#   stateExplanation  stationnumber      type Standort Equipment  \
# 0        available           3751  ELEVATOR                  0
# 1        available           3751  ELEVATOR                  0
# 2        available           6578  ELEVATOR          GLEIS 2/3
# 3        available           6111  ELEVATOR            BSTG. 2
# 4        available           6111  ELEVATOR            BSTG. 1
#
#   TechnPlatzBezeichng                ...                 MIN_TUERBREITE  \
# 0       Bahnsteig 1/4                ...                              0
# ...

# %%
zt = daten_mapped[daten_mapped['Ort'] == 'Bremen Hbf']
    
zt[['equipmentnumber','description','Baujahr']]
# Out:
#      equipmentnumber                  description  Baujahr
# 387         10112296      von Empfangshalle zu OG   1999.0
# 737         10471928   zu Gleis 2/3 Abschnitt B/C   2012.0
# 738         10471929   zu Gleis 5/6 Abschnitt B/C   2013.0
# 739         10471927     zu Gleis 1 Abschnitt B/C   2012.0
# 743         10471931  zu Gleis 9/10 Abschnitt B/C   2013.0
# 744         10471930   zu Gleis 7/8 Abschnitt B/C   2013.0

# %%
# Anzahl aufzüge die Aktiv sind:
print('Anzahl aktiver Aufzüge: ', len(daten[daten['state'] == 'ACTIVE']))
print('Anzahl inaktiver Aufzüge: ', len(daten[daten['state'] == 'INACTIVE']))
print('Anzahl Aufzüge ohne Angabe: ', len(daten[daten['state'] == 'UNKNOWN']))
# Out:
# Anzahl aktiver Aufzüge:  1979
# Anzahl inaktiver Aufzüge:  115
# Anzahl Aufzüge ohne Angabe:  35

# %%
# Gründe für Inaktive Aufzüge
inactive = daten[daten['state'] == 'INACTIVE']

print('Grund1 : not available', len(daten[daten['stateExplanation'] == 'not available']))
print('Grund2 : under construction', len(daten[daten['stateExplanation'] == 'under construction']))
print('Grund3 : under maintenance', len(daten[daten['stateExplanation'] == 'under maintenance']))
# Out:
# Grund1 : not available 69
# Grund2 : under construction 41
# Grund3 : under maintenance 5

# %% [markdown]
# ### Mongo-DB Zugriff

# %%
import json
import pymongo

client = pymongo.MongoClient('mongodb://bart:downy37)tory@localhost:27017/eva')
dbeva = client.eva
facilities = dbeva['facilities']

fac_json_string = '{"equipmentnumber": 99999,"type": "ELEVATOR", "description": "zu Gleis 1","geocoordX": 14.6713589,"geocoordY": 51.0993991,"state": "ACTIVE","stateExplanation": "available","stationnumber": 3751}'
json_obj_active = json.loads(fac_json_string)

fac_json_string = '{"equipmentnumber": 999999,"type": "ELEVATOR", "description": "zu Gleis 1","geocoordX": 14.6713589,"geocoordY": 51.0993991,"state": "INACTIVE","stateExplanation": "available","stationnumber": 3751}'
json_obj_inactive = json.loads(fac_json_string)

json_obj_active
# Out:
# {'equipmentnumber': 99999,
#  'type': 'ELEVATOR',
#  'description': 'zu Gleis 1',
#  'geocoordX': 14.6713589,
#  'geocoordY': 51.0993991,
#  'state': 'ACTIVE',
#  'stateExplanation': 'available',
#  'stationnumber': 3751}

# %%
search_result = dbeva.facilities.find()
#for doc in search_result:
#          print(doc)

# %% [markdown]
# ### Erstellen einer Karte mit inactiven Aufzügen

# %%
# Erzeugen der Karte mit inactiven Aufzügen
# Inaktive Aufzüge:
inactive = daten[daten['state'] == 'INACTIVE']

# Zoom am ausgewählten Ort
geolocator = Nominatim(user_agent="specify_your_app_name_here")

stadt = 'Frankfurt'
bundesland ='Hessen'
land = 'Deutschland'

tmp = str(stadt + ', ' + bundesland + ', ' + land)
location = geolocator.geocode(tmp)

print(location.address)
#print((location.latitude, location.longitude))

x_value = location.latitude
y_value = location.longitude


m = folium.Map(location=[x_value,y_value], zoom_start=10)

for i, row in inactive.iterrows():
    if str(row['geocoordY']) == 'nan' or str(row['geocoordX']) == 'nan':
        pass
    else:
        tmp = str('ID: '+ str(row['equipmentnumber'])+ ' Beschreibung: '+ str(row['description']))
        folium.Marker([row['geocoordY'], row['geocoordX']], 
                      popup = tmp,
                     icon=folium.Icon(color='red', icon='info-sign')).add_to(m)


m.save('map_inactive_elivators_FFM.html')
m
# Out:
# Frankfurt, Regierungsbezirk Darmstadt, Hessen, 60311, Deutschland
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### PHIL TEIL

# %%
import json
import pymongo
import collections
from pprint import pprint
from bson.son import SON  # for aggregate function
from pymongo.command_cursor import CommandCursor
from types import *
import pandas as pd
import numpy as np

from Postgres_Client import PostgreSQL_Zugriff
import psycopg2
import pgdb

import sys
#sys._enablelegacywindowsfsencoding()


def getDesiredState(listWithStates: list, state: str):
    stateCounter = 0

    for i in listWithStates:

        if state == i['state']:
            stateCounter += 1

    return stateCounter


def getDesiredStateExplanation(listWithStates: list, state: str, stateExplanation: str):
    stateExpressionCounter = 0

    for i in listWithStates:

        if state == i['state'] and stateExplanation == i['stateExplanation']:
            stateExpressionCounter += 1

    return stateExpressionCounter


def unique(list1):
    x = np.array(list1)
    return np.unique(x)


def findSingleFacility(equipmentnumber: int, aufzüge):
    resultSingleFacility = facilities.aggregate([

        {'$match': {'type': 'ELEVATOR'}},
        {'$group': {
            '_id': '$equipmentnumber',
            'lastChangeDate': {'$last': '$datetime'}  # ,

        }}
    ])

    # TODO: Notwendig??
    lastID = ''
    lastDatetime = ''

    for i in resultSingleFacility:
        if i['_id'] == equipmentnumber:
            #print(i)
            lastID = i['_id']
            lastDatetime = i['lastChangeDate']

    #print(lastID)
    #print(lastDatetime)

    mappedResult = aufzüge[aufzüge['Equipment'] == lastID]

    mappedResultValues = mappedResult.values

    resultDictionary = {}

    resultDictionary['Stationsnummer'] = mappedResultValues[0][2]
    resultDictionary['Ort'] = mappedResultValues[0][4]
    resultDictionary['Beschreibung'] = mappedResultValues[0][1]
    resultDictionary['Hersteller'] = mappedResultValues[0][6]
    resultDictionary['Baujahr'] = mappedResultValues[0][7]

    return resultDictionary


def readLocallyCSV(path: str):

    # Einlesen der Stammdaten
    aufzüge = pd.read_csv('Stammdaten_Aufzüge.csv', sep=';', engine='python', index_col=False)

    columns = ['Standort Equipment', 'TechnPlatzBezeichng', 'Equipment', 'Equipmentname', 'Ort', 'Wirtschaftseinheit',
               'Hersteller',
               'Baujahr', 'ANTRIEBSART', 'ANZAHL_HALTESTELLEN', 'ANZAHL_TUEREN_KABINE', 'ANZAHL_TUEREN_SCHACHT',
               'FOERDERGESCHWINDIGKEIT',
               'FOERDERHOEHE', 'LAGE', 'TRAGKRAFT', 'ERWEITERTE_ORTSANGABE', 'MIN_TUERBREITE', 'KABINENTIEFE',
               'KABINENBREITE',
               'KABINENHOEHE', 'TUERHOHE', 'FABRIKNUMMER', 'TUERART', 'GEOKOORDINATERECHTSWERT', 'GEOKOORDINATEHOCHWERT',
               'AUSFTEXTLICHEBESCHREIBUNG']

    aufzüge.columns = columns
    aufzüge = aufzüge.drop(0)
    aufzüge['Equipment'] = aufzüge['Equipment'].astype(str).astype('int64')

    return aufzüge


resultDictionary = {}

client = pymongo.MongoClient('mongodb://bart:downy37)tory@localhost:27017/eva', maxPoolSize=50)

dbeva = client.eva

facilities = dbeva['facilities']


############################################################
################# Die Aufzüge im Überblick #################
############################################################

resultOverview = facilities.aggregate([

    {'$match': {'type': 'ELEVATOR'}},

    {'$group': {
        '_id': '$equipmentnumber',
        'lastStateChangeDate': {'$last': '$datetime'},
        'state': {'$last': '$state'},

    }}
])

listWithStates = []

for i in resultOverview:
    listWithStates.append(i)

stateCountACTIVE = getDesiredState(listWithStates, 'ACTIVE')
#print('Anzahl aktiver Aufzüge: ', stateCountACTIVE)

stateCountINACTIVE = getDesiredState(listWithStates, 'INACTIVE')
#print('Anzahl inaktiver Aufzüge: ', stateCountINACTIVE)

stateCountUNKNOWN = getDesiredState(listWithStates, 'UNKNOWN')
#print('Anzahl unbekannter Aufzüge: ', stateCountUNKNOWN)


tempResultDict = {}

tempResultDict['ACTIVE'] = stateCountACTIVE
tempResultDict['INACTIVE'] = stateCountINACTIVE
tempResultDict['UNKNOWN'] = stateCountUNKNOWN

resultDictionary['Overview'] = tempResultDict

print(resultDictionary)
#print(resultDictionary['Overview']['ACTIVE'])


####################################
###### Gründe für Inaktivität ######
####################################

uniqueList = facilities.distinct("stateExplanation");

resultGruendeFuerInaktivitaet = facilities.aggregate([

    {'$match': {'type': 'ELEVATOR'}},

    {'$group': {
        '_id': '$equipmentnumber',
        'lastStateChangeDate': {'$last': '$datetime'},
        'state': {'$last': '$state'},
        'stateExplanation': {'$last': '$stateExplanation'}

    }}
])

listWithStateExplanations = []

for i in resultGruendeFuerInaktivitaet:
    listWithStateExplanations.append(i)

dictStateExplanationReason = {}

for i in uniqueList:

    count = getDesiredStateExplanation(listWithStateExplanations, 'INACTIVE', str(i))

    if count != 0:
        dictStateExplanationReason[str(i)] = count

resultDictionary['ReasonsForInactivity'] = dictStateExplanationReason


print(resultDictionary)


###########################################
### Informationen zu einzelnen Aufzügen ###
###########################################

aufzüge = readLocallyCSV('Stammdaten_Aufzüge.csv')

'''
stammdaten_ziehen = PostgreSQL_Zugriff('my-development-at.my-router.de', 'eva-user', 'downy37tory', 'postgres')
stammdaten = stammdaten_ziehen.zugriff()
print('### stammdaten ###')
print(stammdaten)
'''

singleFacility = findSingleFacility(10499641, aufzüge)

print('### singleFacility ###')
print(singleFacility)


##################################
########## Wissenwertes ##########
##################################

aeltesteAufzug = int(aufzüge['Baujahr'].min())
neuesteAufzug = int(aufzüge['Baujahr'].max())
# Out:
# {'Overview': {'ACTIVE': 1979, 'INACTIVE': 122, 'UNKNOWN': 38}}
# {'Overview': {'ACTIVE': 1979, 'INACTIVE': 122, 'UNKNOWN': 38}, 'ReasonsForInactivity': {'not available': 79, 'under construction': 37, 'under maintenance': 6}}
# ### singleFacility ###
# {'Stationsnummer': 10499641, 'Ort': 'Löbau (Sachs)', 'Beschreibung': 'Bahnsteig 1/4', 'Hersteller': 'Schindler Aufzüge', 'Baujahr': 2015.0}

# %%
atz = aufzüge[aufzüge['Baujahr'] == int(aufzüge['Baujahr'].min())]

atu = aufzüge[aufzüge['Baujahr'] == int(aufzüge['Baujahr'].max())]

atz['Ort'].values[0]
int(atz['Baujahr'].values[0])
# Out:
# 1948

# %%
dictStateExplanationReason
# Out:
# {'not available': 79, 'under construction': 37, 'under maintenance': 6}

# %%
tmp1 = []
tmp2 = []

for key, value in dictStateExplanationReason.items():
    tmp1.append(key)
    tmp2.append(value)
    
print(tmp1)
print(tmp2)
# Out:
# ['not available', 'under construction', 'under maintenance']
# [79, 37, 6]

# %%
tmp3 = aufzüge[aufzüge['Equipment'] == 10001649]

fg = tmp3['TechnPlatzBezeichng'].values

fg[0]
# Out:
# 'Bahnsteig 01 Richtung Aachen'

# %%
tmp6 = facilities.aggregate([

    {'$match': {'type': 'ELEVATOR'}},
    {'$group': {
        '_id': '$equipmentnumber',
        'description': {'$last': '$description'},
        'geocoordX': {'$last': '$geocoordX'},
        'geocoordY': {'$last': '$geocoordY'},
        'lastStateChangeDate': {'$last': '$datetime'},
        'state': {'$last': '$state'},
    }}
])

from pandas import DataFrame
tmp6 = pd.DataFrame(list(tmp6))

tmp6.columns = ['equipmentnumber', 'description', 'geocoordX', 'geocoordY', 'lastStateChangeDate', 'state']
tmp6.head()
# Out:
#    equipmentnumber            description  geocoordX  geocoordY  \
# 0         10571157                   None        NaN        NaN
# 1         10508084                Gleis 3  10.015890  47.826360
# 2         10546300           zu Gleis 1/2  10.913737  50.001252
# 3         10194692  zu Gleis 1/2 (S-Bahn)   9.172030  48.775400
# 4         10502478                   None        NaN        NaN
#
#    lastStateChangeDate     state
# 0  2018-07-20_07-15-10  INACTIVE
# 1  2018-08-05_12-36-04    ACTIVE
# 2  2018-08-05_12-55-16    ACTIVE
# 3  2018-08-05_12-23-30    ACTIVE
# 4  2018-08-05_12-36-04    ACTIVE

# %%
tmp7 = tmp6[tmp6['state'] == 'INACTIVE']

len(tmp7)
# Out:
# 122

# %%
# Erzeugen der Karte mit inactiven Aufzügen
# Inaktive Aufzüge:
inactive = tmp7

# Zoom am ausgewählten Ort
geolocator = Nominatim(user_agent="Eva_Dashboard")

stadt = 'Frankfurt'
bundesland ='Hessen'
land = 'Deutschland'

tmp = str(stadt + ', ' + bundesland + ', ' + land)
location = geolocator.geocode(tmp)

x_value = location.latitude
y_value = location.longitude


m = folium.Map(location=[x_value,y_value], zoom_start=10)

for i, row in inactive.iterrows():
    if str(row['geocoordY']) == 'nan' or str(row['geocoordX']) == 'nan':
        pass
    else:
        tmp = str('ID: '+ str(row['equipmentnumber'])+ ' Beschreibung: '+ str(row['description']))
        folium.Marker([row['geocoordY'], row['geocoordX']], 
                      popup = tmp,
                     icon=folium.Icon(color='red', icon='info-sign')).add_to(m)


#m.save('map_inactive_elivators_FFM.html')

# %%
tmp9 = facilities.aggregate([

    {'$match': {'type': 'ELEVATOR'}},

])

tmp10 = pd.DataFrame(list(tmp9))

# %%
tmp11 = tmp10[tmp10['equipmentnumber'] == 10499641]

# %%
tmp12 = tmp11[['datetime', 'state', 'stateExplanation']].head(10)

# %%
tmp13 = facilities.find({"type": "ELEVATOR", "equipmentnumber": 10499641})
tmp13 = pd.DataFrame(list(tmp13))

# %%
tmp13 = tmp13[['datetime', 'state', 'stateExplanation']]

# %%
tmp14 = tmp13[::-1]

# %%
tmp14
# Out:
#                datetime     state      stateExplanation
# 14  2018-08-24_16-22-41    ACTIVE             available
# 13  2018-08-24_15-30-07  INACTIVE         not available
# 12  2018-08-06_12-49-38    ACTIVE             available
# 11  2018-08-06_08-06-06  INACTIVE         not available
# 10  2018-08-05_12-36-04    ACTIVE             available
# 9   2018-08-05_02-03-17   UNKNOWN  monitoring disrupted
# 8   2018-08-02_22-26-59    ACTIVE             available
# 7   2018-08-02_15-03-50  INACTIVE         not available
# 6   2018-08-01_23-21-21    ACTIVE             available
# 5   2018-08-01_13-24-02  INACTIVE         not available
# 4   2018-07-31_23-09-07    ACTIVE             available
# 3   2018-07-31_15-36-52  INACTIVE         not available
# 2   2018-06-27_12-50-42    ACTIVE             available
# 1   2018-06-27_12-32-03  INACTIVE         not available
# 0   2018-06-09_12-30-04    ACTIVE             available
